# %%
pip install stable-baselines3[extra]

# %%
import gymnasium as gym
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make("LunarLander-v2",render_mode = 'rgb_array')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DQN("MlpPolicy", env,device=device, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=int(2e5), progress_bar=True)

# Save the agent
model.save("dqn_lunar")

# Load the trained agent
model = DQN.load("dqn_lunar", env=env)

# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# C:\Users\Raj\anaconda3\envs\DLR\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4578     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.6     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5160     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 613      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.4     |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5288     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 989      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.4     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5208     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5402     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.8     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5538     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5554     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5617     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.1     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5656     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5681     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.2     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5677     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.9     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.1     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5657     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.6     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5667     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.7     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.7     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5683     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5483     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.9     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5695     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5716     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5725     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5736     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5719     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5719     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.608    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5727     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5707     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5724     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8959     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5729     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5721     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2562     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 10019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2614     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 10442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2668     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2716     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2762     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2807     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2850     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 12170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2892     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 12527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2936     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 12903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2977     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 13256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3016     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 13610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3060     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 14048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3097     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 14391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2945     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 15703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.237    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2979     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 16059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3011     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 16393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.204    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3047     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 16756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3084     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3121     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.149    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3156     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 17926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.128    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3192     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 18355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.113    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3220     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 18668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.0947   |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3252     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 19058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.0786   |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3280     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 19398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.0629   |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3309     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 19728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3335     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 20056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3365     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 20437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3396     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 20830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3419     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 21147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3442     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 21473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3469     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 21876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3493     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 22256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3514     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 22559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3545     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 22987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3568     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 23359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3593     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 23718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3615     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 24095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3635     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 24424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3653     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 24725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3676     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 25099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3697     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 25465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3717     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 25816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3735     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 26132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3754     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 26498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3776     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 26879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3794     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 27243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3811     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 27547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3829     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 27911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3846     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 28272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3864     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 28654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3879     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 29033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3893     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 29465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3907     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 29882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3921     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3934     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 30678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3951     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3963     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3977     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 31797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3987     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 32142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3999     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 32450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4012     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 32772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4025     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 33084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4040     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 33466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4055     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 33806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 4069     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 4083     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 4096     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 34882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 4106     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 4119     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 4130     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 35952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 4140     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 4153     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 4167     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 37036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 4180     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 37399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 4192     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 37801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 4202     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 4215     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 4227     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 38805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 4240     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 4253     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 4262     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 39796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 4273     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 4282     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 4291     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 40822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 4300     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 41137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 4314     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 41543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 4326     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 41901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 4339     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 42296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 4352     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 42624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 4363     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 42965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 4378     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 43390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 4390     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 43736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 4403     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 44150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 4413     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 44452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 4426     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 44841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 4437     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 45178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 4448     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 45506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 700      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 100936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.543    |
# |    n_updates        | 12733    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 534      |
# |    ep_rew_mean      | -248     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 696      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 102692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.544    |
# |    n_updates        | 13172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | -247     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 682      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 105951   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.61     |
# |    n_updates        | 13987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 578      |
# |    ep_rew_mean      | -242     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 676      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 107811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.61     |
# |    n_updates        | 14452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | -213     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 669      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 110396   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.657    |
# |    n_updates        | 15098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 617      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 664      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 112576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.469    |
# |    n_updates        | 15643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 644      |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 656      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 115896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.6      |
# |    n_updates        | 16473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 659      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 653      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 117880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.545    |
# |    n_updates        | 16969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 684      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 648      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 120890   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.463    |
# |    n_updates        | 17722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 694      |
# |    ep_rew_mean      | -100     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 641      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 123935   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.443    |
# |    n_updates        | 18483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 685      |
# |    ep_rew_mean      | -97.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 637      |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 126336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.617    |
# |    n_updates        | 19083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 675      |
# |    ep_rew_mean      | -90.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 633      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 128891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3        |
# |    n_updates        | 19722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 682      |
# |    ep_rew_mean      | -90.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 622      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 132891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.86     |
# |    n_updates        | 20722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 680      |
# |    ep_rew_mean      | -87.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 619      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 135902   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.806    |
# |    n_updates        | 21475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 684      |
# |    ep_rew_mean      | -88.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 612      |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 139246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.504    |
# |    n_updates        | 22311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 692      |
# |    ep_rew_mean      | -87.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 605      |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 143246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.301    |
# |    n_updates        | 23311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | -90.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 597      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 147246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.625    |
# |    n_updates        | 24311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | -87.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 592      |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 151101   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.665    |
# |    n_updates        | 25275    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | -84.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 587      |
# |    time_elapsed     | 263      |
# |    total_timesteps  | 154709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.698    |
# |    n_updates        | 26177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 721      |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 580      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 158146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.58     |
# |    n_updates        | 27036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 721      |
# |    ep_rew_mean      | -80.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 576      |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 162146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.494    |
# |    n_updates        | 28036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 744      |
# |    ep_rew_mean      | -81.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 569      |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 166146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.55     |
# |    n_updates        | 29036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | -84      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 564      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 170146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.531    |
# |    n_updates        | 30036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | -83.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 556      |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 174146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.9      |
# |    n_updates        | 31036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 789      |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 553      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 178146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.624    |
# |    n_updates        | 32036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 812      |
# |    ep_rew_mean      | -88.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 549      |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 182146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 33036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 835      |
# |    ep_rew_mean      | -88.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 544      |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 186146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.659    |
# |    n_updates        | 34036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 842      |
# |    ep_rew_mean      | -89      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 542      |
# |    time_elapsed     | 350      |
# |    total_timesteps  | 190146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.473    |
# |    n_updates        | 35036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 863      |
# |    ep_rew_mean      | -91.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 536      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 194146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.763    |
# |    n_updates        | 36036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 878      |
# |    ep_rew_mean      | -91.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 533      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 198146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.689    |
# |    n_updates        | 37036    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
